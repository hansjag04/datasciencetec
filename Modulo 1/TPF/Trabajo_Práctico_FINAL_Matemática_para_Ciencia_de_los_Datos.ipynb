# %% [markdown]
# # Matemática para Ciencia de los Datos
# # Trabajo_Práctico_4
#
# Juan Luis Crespo Mariño
#
# Instituto Tecnológico de Costa Rica,
#
# Laboratorio LIANA (Laboratorio de IA para las Ciencias Naturales). Área Académica de Ingeniería Mecatrónica.
#
# PAttern Recongition and MAchine Learning Group (PARMA-Group)
#
# ---
#
# Fecha de entrega: Viernes 29 de Noviembre del 2019, a más tardar a las 6:00 pm.
#
# Medio de entrega: Por medio del TEC-Digital.
#
# Entregables: Un archivo .zip con: archivo jupyter ( .IPYNB ), el archivo tipo LyX y su pdf generado (opcional).
#
# Modo de trabajo: Parejas.
#
#
# ---
#
#
#
# Resumen: En el presente trabajo práctico se ralizará un proyecto de carácter global. Por lo cual, es especialmente importante explicar lo realizado, la forma realizada y el análisis de los resultados teniendo muy presentes los términos y conceptos estudiados durante la totalidad del curso. La puntuación supone el 25 % del total del curso
#
#
# ---

# %% [markdown]
# **Planteamiento**
#
# En el archivo csv presente en la misma carpeta se muestran datos correspondientes a un conjunto de variables que nos puede permitir determinar si un paciente es o no diabético.
#
# Se trata de 8 columnas que corresponden a :
#
# 0. ESTA COLUMNA NO SE VA A UTILIZAR
# 1. Concentración de glucosa en plasma
# 2. Presión sanguínea diastólica
# 3. Grosor de los pliegues cutáneos
# 4. Concentración de insulina en suero a las 2 horas
# 5. Índice de masa corporal
# 6. Función de herencia de diabetes
# 7. Edad
#
# Y una columna adicional, binaria, que señala si el paciente es diabético (1) o no (0)
#
# Lo que tienen que hacer es lo siguiente:
#
#
# 1 – elijan tres combinaciones de tres de las variables, las que ustedes quieran (obviamente habrá variables que se repetirán)
#
# 2 – grafiquen los puntos, poniendo un color a los de la categoría diabéticos y otro color a los de la categoría no diabéticos **(20 puntos)**
#
# 3 – analicen cuan fácil o difícil es, así como el grado de errores que se cometerían, al tratar de separar ambas categorías. Pueden ustedes hacer al respecto un análisis cualitativo o incluso cuantitativo **(30 puntos)**
#
# 4 - ahora, lleven a cabo un proceso de reducción de dimensiones, basado en la técnica PCA, respondiendo a las siguientes cuestiones **(50 puntos)**
#
#   4.1 - ¿cual es la función de varianza exhibida por cada una de las CP? Razone la respuesta
#
#   4.2 - en función de los valores de los "loadings" ¿que conclusiones puede establecer sobre la varianza de las diferentes variables originales? Razone la respuesta
#
#   4.3 - si usted reduce el conjunto de variables originales a un conjunto de 3 CP ¿cual es la diferencia con los ejemplos que constituyen sus respuestas al apartado 1 de este trabajo? FIJESE QUE NO SE PIDE COMPARAR RESULTADOS SINO diferencias entre la naturaleza de lo mostrado. Razone la respuesta
#
#
# PD: les adjunto asimismo un archivo pytorch de una tarea que utiliza este mismo conjunto de datos, pueden ustedes usar el código de éste como gusten.
#
#
#
# ---
